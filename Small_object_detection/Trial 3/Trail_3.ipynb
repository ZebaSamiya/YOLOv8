# %% [markdown]
# ## Loading YOLOv8 Model

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
model.info()
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %% [markdown]
# ## Training Model

# %%
results = model.train(
    data="traffic-sign-detection-yolov8-10/data.yaml",
    epochs=40,
    imgsz=1024,
    batch=16,
    optimizer='AdamW',
    lr0=0.005,
    lrf=0.0002,
    momentum=0.93,
    weight_decay=0.0005,
    iou=0.45,
    conf=0.4,
    mosaic=0.8,
    scale=0.4,
    flipud=0.4,
    fliplr=0.5,
    degrees=5,
    save=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.92 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# ...

# %% [markdown]
# ## Running Inference

# %%
import os
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Enable inline plotting for Jupyter
# %matplotlib inline  

# Define paths
test_images_folder = "./traffic-sign-detection-yolov8-10/test/images"
output_folder = "./detections"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Load YOLO model
model = YOLO("runs/detect/train6/weights/best.pt")  # Ensure correct model file

# Run inference on all images
for image_name in sorted(os.listdir(test_images_folder)):
    if image_name.endswith((".jpg", ".png", ".jpeg")):
        image_path = os.path.join(test_images_folder, image_name)

        # Run inference
        results = model(image_path, conf=0.5, iou=0.4)

        # Save detected image
        for result in results:
            output_image = result.plot()
            output_path = os.path.join(output_folder, f"detected_{image_name}")
            cv2.imwrite(output_path, output_image)

        # print(f"Processed: {image_name} -> Saved to {output_path}")

print("Inference completed on all test images!")

# Function to display detected images
def show_detected_images(folder_path, num_images=16):
    image_files = sorted(os.listdir(folder_path))[:num_images]

    if not image_files:
        print("No detected images found!")
        return

    rows, cols = 4, 4
    fig, axes = plt.subplots(rows, cols, figsize=(15, 15))

    for i, img_file in enumerate(image_files):
        img_path = os.path.join(folder_path, img_file)
        print(f"Loading: {img_path}")  # Debugging step
        img = cv2.imread(img_path)

        if img is None:
            print(f" Warning: Failed to load {img_file}")
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        row, col = divmod(i, cols)
        axes[row, col].imshow(img)
        axes[row, col].axis("off")
        axes[row, col].set_title(img_file, fontsize=10)

    plt.tight_layout()
    plt.show()

# Show images
show_detected_images(output_folder, num_images=16)
# Out:
# image 1/1 /home/vbyaramadulokesh/yolo/traffic-sign-detection-yolov8-10/test/images/00217_jpg.rf.ba5ade3eafba67712065486fecb5483c.jpg: 768x1024 1 traffic-signs, 63.7ms
# Speed: 6.6ms preprocess, 63.7ms inference, 14.9ms postprocess per image at shape (1, 3, 768, 1024)
#
# image 1/1 /home/vbyaramadulokesh/yolo/traffic-sign-detection-yolov8-10/test/images/00318_jpg.rf.bcdd29521712c84a2ace989c390bda35.jpg: 768x1024 2 traffic-signss, 9.5ms
# Speed: 5.8ms preprocess, 9.5ms inference, 12.4ms postprocess per image at shape (1, 3, 768, 1024)
#
# image 1/1 /home/vbyaramadulokesh/yolo/traffic-sign-detection-yolov8-10/test/images/00355_jpg.rf.c1a2f426e05f952833b0f544ed8f8cc8.jpg: 768x1024 1 traffic-signs, 9.4ms
# Speed: 6.1ms preprocess, 9.4ms inference, 12.4ms postprocess per image at shape (1, 3, 768, 1024)
#
# image 1/1 /home/vbyaramadulokesh/yolo/traffic-sign-detection-yolov8-10/test/images/00362_jpg.rf.f0ae1e0ae6a86b49c5cfa765557e9116.jpg: 768x1024 2 traffic-signss, 8.8ms
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.90 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# val: Scanning /home/vbyaramadulokesh/yolo/traffic-sign-detection-yolov8-10/valid/labels.cache... 196 images, 1 backgrounds, 0 corrupt: 100%|██████████| 196/196 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:06<00:00,  1.94it/s]
#                    all        196        319      0.966      0.901      0.957      0.626
# Speed: 2.3ms preprocess, 2.8ms inference, 0.0ms loss, 7.6ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f2a52a85390>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...

# %%
from IPython.display import Image
Image(filename=f'./runs/detect/train6/results.png')

# %%
Image(filename=f'runs/detect/train6/P_curve.png')

# %%
Image(filename=f'runs/detect/train6/confusion_matrix_normalized.png')
